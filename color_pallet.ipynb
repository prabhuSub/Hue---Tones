# %%
import colour
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = mpimg.imread('./images/Van Gogh starry_night_full_1889.jpg')
imgplot = plt.imshow(img)
plt.show()

# %%
import PIL
from PIL import Image
from matplotlib import pyplot as plt

im = Image.open('./images/Van Gogh starry_night_full_1889.jpg')  
w, h = im.size  
colors = im.getcolors(w*h)

def hexencode(rgb):
    r=rgb[0]
    g=rgb[1]
    b=rgb[2]
    return '#%02x%02x%02x' % (r,g,b)

for idx, c in enumerate(colors):
     plt.bar(idx, c[0], color=hexencode(c[1]),edgecolor=hexencode(c[1]))

plt.show()

# %% [markdown]
# ### Extracting colors from the image and converting them to HEX values. Trying to plot Histogram based on their frequency in the images

# %%
from PIL import Image
im = Image.open('./images/Van Gogh starry_night_full_1889.jpg')
from collections import defaultdict
by_color = defaultdict(int)
for pixel in im.getdata():
    by_color[pixel] += 1
# by_color
sort_colors = sorted(by_color.items(), key=lambda x: x[1], reverse=True)
diction_color = {}
for section in sort_colors:
    diction_color[section[0]] = section[1]
# diction_color
print(len(diction_color.keys()))
print(len(diction_color.values()))
keys = list(diction_color.keys())
values = list(diction_color.values())
hex_value_color = []
for k in keys:
    hex_value_color.append('#%02x%02x%02x' % k)
# hex_value_color
# Out:
# 227521
# 227521

# %%
# by_color

# %%
# desired_list = list(diction_color.keys())[0:50]
desired_list = list(by_color.keys())[0:50]
desired_list
hex_value_color_desired = []
for k in desired_list:
    hex_value_color_desired.append('#%02x%02x%02x' % k)
# hex_value_color_desired

# %%
import seaborn as sns
colors = np.array(desired_list) / 255

sns.palplot(colors)

# %%
plt.figure(figsize=(40,10))
barlist = plt.bar(hex_value_color_desired, list(by_color.values())[0:50])
i = 0
plt.xlabel("Color Codes(HEX)")
plt.ylabel("Number of Pixels")
for bars in barlist:
    bars.set_color(hex_value_color_desired[i])
    i+=1
